# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %% [markdown]
# ### Random advices

# %% [markdown]
# Gives you random advices

# %%
# Import requests library
import pandas as pd
import requests
import json
from pandas import json_normalize

# %%
advice = requests.get("https://api.adviceslip.com/advice").json()
advice
# Out:
# {'slip': {'id': 134,
#   'advice': 'The person who never made a mistake never made anything.'}}

# %% [markdown]
# ### Fruits

# %% [markdown]
# Nutrition information about fruit

# %%
fruits = requests.get('https://www.fruityvice.com//api/fruit/all').json()
fruits
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Persea',
#   'name': 'Avocado',
#   'id': 84,
#   'family': 'Lauraceae',
#   'order': 'Laurales',
#   'nutritions': {'carbohydrates': 8.53,
#    'protein': 2,
#    'fat': 14.66,
#    'calories': 160,
#    'sugar': 0.66}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Rubus',
#   'name': 'Blackberry',
#   'id': 64,
# ...

# %%
flattened_data = json_normalize(fruits)

# %%
flattened_data.head()
# Out:
#     genus        name  id     family         order  nutritions.carbohydrates  \
# 0   Malus       Apple   6   Rosaceae       Rosales                     11.40
# 1  Prunus     Apricot  35   Rosaceae       Rosales                      3.90
# 2  Persea     Avocado  84  Lauraceae      Laurales                      8.53
# 3    Musa      Banana   1   Musaceae  Zingiberales                     22.00
# 4   Rubus  Blackberry  64   Rosaceae       Rosales                      9.00
#
#    nutritions.protein  nutritions.fat  nutritions.calories  nutritions.sugar
# 0                 0.3            0.40                   52             10.30
# 1                 0.5            0.10                   15              3.20
# 2                 2.0           14.66                  160              0.66
# 3                 1.0            0.20                   96             17.20
# 4                 1.3            0.40                   40              4.50

# %% [markdown]
# ### Dog facts

# %% [markdown]
# Random dog facts

# %%
dogs = requests.get('http://dog-api.kinduff.com/api/facts').json()
dogs
# Out:
# {'facts': ['Obesity is the #1 health problem among dogs.'], 'success': True}

# %% [markdown]
# ### Books - John Ronald Reuel Tolkien

# %%
books = requests.get('http://openlibrary.org/search.json?author=tolkien')

# %%
results = books.json()

# %%
results
# Out:
# {'numFound': 630,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'key': '/works/OL262758W',
#    'type': 'work',
#    'seed': ['/books/OL28345239M',
#     '/books/OL9228183M',
#     '/books/OL9228706M',
#     '/books/OL7880665M',
#     '/books/OL7591523M',
#     '/books/OL22146871M',
#     '/books/OL9403108M',
#     '/books/OL6363476M',
#     '/books/OL6366662M',
#     '/books/OL7465523M',
#     '/books/OL20388227M',
#     '/books/OL22306424M',
#     '/books/OL26215711M',
#     '/books/OL20352933M',
#     '/books/OL22804790M',
#     '/books/OL24595247M',
#     '/books/OL26477626M',
#     '/books/OL22368666M',
#     '/books/OL7273993M',
#     '/books/OL17911508M',
#     '/books/OL22761592M',
#     '/books/OL9228702M',
#     '/books/OL5550061M',
#     '/books/OL13875540M',
#     '/books/OL24821416M',
#     '/books/OL22788094M',
#     '/books/OL24375966M',
#     '/books/OL21080822M',
#     '/books/OL21755817M',
#     '/books/OL22369858M',
#     '/books/OL21563144M',
# ...

# %%
flattened_data = json_normalize(results['docs'])

# %%
flattened_data
# Out:
#                    key  type  \
# 0     /works/OL262758W  work
# 1      /works/OL27448W  work
# 2      /works/OL27479W  work
# 3      /works/OL27516W  work
# 4   /works/OL14933414W  work
# ..                 ...   ...
# 95  /works/OL25483632W  work
# 96  /works/OL21800645W  work
# 97  /works/OL21887224W  work
# 98   /works/OL8997777W  work
# 99   /works/OL8997780W  work
#
#                                                  seed  \
# 0   [/books/OL28345239M, /books/OL9228183M, /books...
# 1   [/books/OL9158246M, /books/OL9177076M, /books/...
# 2   [/books/OL27296256M, /books/OL31879906M, /book...
# 3   [/books/OL31905946M, /books/OL9924431M, /books...
# 4   [/books/OL8889789M, /books/OL22266040M, /books...
# ..                                                ...
# 95  [/books/OL34277064M, /books/OL34179319M, /work...
# 96  [/books/OL29693941M, /books/OL30819626M, /work...
# 97  [/books/OL29848936M, /works/OL21887224W, /auth...
# 98  [/books/OL9076654M, /works/OL8997777W, /author...
# ...

# %% [markdown]
# ### Historical Flight Data

# %% [markdown]
# Even though I have a key, did not work. I will email them

# %% [markdown]
# When I use get pass >>>> error 403,   enter the key manually error 401

# %%
import getpass
apikey = getpass.getpass()
# Out:
# ········

# %%
flights = requests.get('https://api.aviationstack.com/v1/flights?access_key='+apikey+'&flight_date=2019-12-11')

# %%
flights
# Out:
# <Response [403]>

# %%
flights2 = requests.get('https://api.aviationstack.com/v1/aircraft_types?access_key='+apikey)

# %%
flights2
# Out:
# <Response [403]>
